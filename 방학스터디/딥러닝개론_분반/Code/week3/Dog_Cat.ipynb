# %%
train_data_path = "/home/duhyeong.lee.conda/DogCat/train/"
test_data_path = "/home/duhyeong.lee.conda/DogCat/test1/"
sample_submission_path = "/home/duhyeong.lee.conda/DogCat/sampleSubmission.csv"

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("../DogCat"))
# Out:
# ['sampleSubmission.csv', '.ipynb_checkpoints', 'Untitled.ipynb', 'train.zip', 'dogs-vs-cats.zip', 'test1.zip', 'train', 'test1', 'dogs_vs_cats_photos.npy', 'dogs_vs_cats_labels.npy', 'dataset_dogs_vs_cats', 'Untitled1.ipynb', 'Untitled2.ipynb']

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
filenames = os.listdir("../DogCat/train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#        filename  category
# 0     cat.0.jpg         0
# 1     cat.1.jpg         0
# 2    cat.10.jpg         0
# 3   cat.100.jpg         0
# 4  cat.1000.jpg         0

# %%
df.tail()
# Out:
#            filename  category
# 24995  dog.9995.jpg         1
# 24996  dog.9996.jpg         1
# 24997  dog.9997.jpg         1
# 24998  dog.9998.jpg         1
# 24999  dog.9999.jpg         1

# %%
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import random
sample = random.choice(filenames)
image = load_img("../DogCat/train/"+sample)
plt.imshow(image)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=273x212 at 0x7F47CB2CD630>

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
earlystop = EarlyStopping(patience=10)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "../DogCat/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "../DogCat/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "../DogCat/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From <ipython-input-22-b9bf4bfec1d9>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.7500 - accuracy: 0.6306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.7500 - accuracy: 0.6306 - val_loss: 0.5718 - val_accuracy: 0.7165
# Epoch 2/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.5474 - accuracy: 0.7292WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.5474 - accuracy: 0.7292 - val_loss: 0.5235 - val_accuracy: 0.7451
# Epoch 3/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.7643WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.4964 - accuracy: 0.7643 - val_loss: 0.5234 - val_accuracy: 0.7766
# Epoch 4/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.7872WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.4569 - accuracy: 0.7872 - val_loss: 0.4576 - val_accuracy: 0.7712
# Epoch 5/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.8045WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.4319 - accuracy: 0.8045 - val_loss: 0.3443 - val_accuracy: 0.8486
# Epoch 6/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.4169 - accuracy: 0.8124WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.4169 - accuracy: 0.8124 - val_loss: 0.7040 - val_accuracy: 0.7193
# Epoch 7/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8229WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3972 - accuracy: 0.8229 - val_loss: 0.3359 - val_accuracy: 0.8535
# Epoch 8/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3829 - accuracy: 0.8313WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3829 - accuracy: 0.8313 - val_loss: 0.3854 - val_accuracy: 0.8400
# Epoch 9/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3811 - accuracy: 0.8338WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3811 - accuracy: 0.8338 - val_loss: 0.3543 - val_accuracy: 0.8569
# Epoch 10/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8404WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3674 - accuracy: 0.8404 - val_loss: 0.4790 - val_accuracy: 0.7479
# Epoch 11/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8501WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3536 - accuracy: 0.8501 - val_loss: 0.3099 - val_accuracy: 0.8683
# Epoch 12/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.8460WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3533 - accuracy: 0.8460 - val_loss: 0.3352 - val_accuracy: 0.8643
# Epoch 13/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8473WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3507 - accuracy: 0.8473 - val_loss: 0.2828 - val_accuracy: 0.8817
# Epoch 14/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8538WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3413 - accuracy: 0.8538 - val_loss: 0.2410 - val_accuracy: 0.9043
# Epoch 15/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3359 - accuracy: 0.8558WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3359 - accuracy: 0.8558 - val_loss: 0.2891 - val_accuracy: 0.8809
# Epoch 16/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3301 - accuracy: 0.8566WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3301 - accuracy: 0.8566 - val_loss: 0.3921 - val_accuracy: 0.8563
# Epoch 17/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3284 - accuracy: 0.8593WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.3284 - accuracy: 0.8593 - val_loss: 0.3004 - val_accuracy: 0.8791
# Epoch 18/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.8602WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3257 - accuracy: 0.8602 - val_loss: 0.2627 - val_accuracy: 0.8931
# Epoch 19/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8684WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3146 - accuracy: 0.8684 - val_loss: 0.2828 - val_accuracy: 0.8811
# Epoch 20/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8676WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3089 - accuracy: 0.8676 - val_loss: 0.2767 - val_accuracy: 0.8867
# Epoch 21/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3126 - accuracy: 0.8648WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3126 - accuracy: 0.8648 - val_loss: 0.3503 - val_accuracy: 0.8767
# Epoch 22/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3083 - accuracy: 0.8689WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3083 - accuracy: 0.8689 - val_loss: 0.2834 - val_accuracy: 0.9013
# Epoch 23/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8718WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.3022 - accuracy: 0.8718 - val_loss: 0.3040 - val_accuracy: 0.8785
# Epoch 24/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2939 - accuracy: 0.8777WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2939 - accuracy: 0.8777 - val_loss: 0.2346 - val_accuracy: 0.9057
# Epoch 25/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.8743WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2949 - accuracy: 0.8743 - val_loss: 0.3000 - val_accuracy: 0.8697
# Epoch 26/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8776WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2901 - accuracy: 0.8776 - val_loss: 0.4016 - val_accuracy: 0.8346
# Epoch 27/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2976 - accuracy: 0.8753WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2976 - accuracy: 0.8753 - val_loss: 0.5861 - val_accuracy: 0.7882
# Epoch 28/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.8781WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2909 - accuracy: 0.8781 - val_loss: 0.2790 - val_accuracy: 0.8943
# Epoch 29/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.8771WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2895 - accuracy: 0.8771 - val_loss: 0.3077 - val_accuracy: 0.8983
# Epoch 30/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.8795WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2887 - accuracy: 0.8795 - val_loss: 0.2459 - val_accuracy: 0.9061
# Epoch 31/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2875 - accuracy: 0.8811WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2875 - accuracy: 0.8811 - val_loss: 0.2710 - val_accuracy: 0.9087
# Epoch 32/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8791WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2846 - accuracy: 0.8791 - val_loss: 0.2354 - val_accuracy: 0.9015
# Epoch 33/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.8832WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2772 - accuracy: 0.8832 - val_loss: 0.2186 - val_accuracy: 0.9149
# Epoch 34/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.8830WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2780 - accuracy: 0.8830 - val_loss: 0.2125 - val_accuracy: 0.9187
# Epoch 35/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8844WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2799 - accuracy: 0.8844 - val_loss: 0.2479 - val_accuracy: 0.9077
# Epoch 36/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.8857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2743 - accuracy: 0.8857 - val_loss: 0.2365 - val_accuracy: 0.9109
# Epoch 37/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.8866WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2748 - accuracy: 0.8866 - val_loss: 0.3325 - val_accuracy: 0.8581
# Epoch 38/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.8875WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2713 - accuracy: 0.8875 - val_loss: 0.3803 - val_accuracy: 0.8316
# Epoch 39/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.8885WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2664 - accuracy: 0.8885 - val_loss: 0.2307 - val_accuracy: 0.9053
# Epoch 40/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2675 - accuracy: 0.8868WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2675 - accuracy: 0.8868 - val_loss: 0.3402 - val_accuracy: 0.8579
# Epoch 41/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.8849WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2679 - accuracy: 0.8849 - val_loss: 0.3046 - val_accuracy: 0.8623
# Epoch 42/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8846WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2760 - accuracy: 0.8846 - val_loss: 0.5009 - val_accuracy: 0.7864
# Epoch 43/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.8918WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 123s 92ms/step - loss: 0.2636 - accuracy: 0.8918 - val_loss: 0.2205 - val_accuracy: 0.9205
# Epoch 44/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.8906WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 122s 92ms/step - loss: 0.2704 - accuracy: 0.8906 - val_loss: 0.4837 - val_accuracy: 0.8482

# %%
model.save_weights("model.h5")

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['acc'], color='b', label="Training accuracy")
ax2.plot(history.history['val_acc'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e2e665c6f039> in <module>()
#       5 ax1.set_yticks(np.arange(0, 1, 0.1))
#       6
# ----> 7 ax2.plot(history.history['acc'], color='b', label="Training accuracy")
#       8 ax2.plot(history.history['val_acc'], color='r',label="Validation accuracy")
#       9 ax2.set_xticks(np.arange(1, epochs, 1))
#
# KeyError: 'acc'

# %%
test_filenames = os.listdir("../DogCat/test1")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "../DogCat/test1/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# WARNING:tensorflow:From <ipython-input-28-6056e543bb97>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
test_df['category'] = np.argmax(predict, axis=-1)
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })
test_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("../DogCat/test1/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()

# %%
# Out:
# <AxesSubplot:>
