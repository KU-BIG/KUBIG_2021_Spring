# %% [markdown]
# 1. for loop를 이용하여 'DataCamp' 각 알파벳의 순서를 key, 알파벳을 value로 갖는 딕셔너리 만들고, 다음과 같이 출력하기.(Hint. enumerate, start)
#
# (Output_Example)
#
# 1번째 알파벳은 D입니다.
#
# 2번째 알파벳은 a입니다.
#
# 3번째 알파벳은 t입니다.
#
# 4번째 알파벳은 a입니다.
#
# 5번째 알파벳은 C입니다.
#
# 6번째 알파벳은 a입니다.
#
# 7번째 알파벳은 m입니다.
#
# 8번째 알파벳은 p입니다.

# %% [markdown]
# 2.  nation = ('China','Japan','Taiwan','Hong Kong','Macao','Phillipines')
#
#     visitor = (392814,206526,87954,35896,2570,30473)
#
#     을 이용하여 다음과 같은 딕셔너리 만들어 출력하기.
#
# {'China': 392814, 'Japan': 206526, 'Taiwan': 87954, 'Hong Kong': 35896, 'Macao': 2570, 'Phillipines': 30473}

# %% [markdown]
# 3. Enter_korea_by_age.csv와 chunk(chunksize = 1000)을 이용하여
#
#     1) 2019년 1월부터 2020년 4월까지 방문객 총 합 구하기
#
#     2) 2019년 1월부터 2020년 4월까지 21세~30세 방문객 총 합 구하기

# %% [markdown]
# ![스크린샷 2021-02-06 오전 10.30.17.png](data:image/png;base64,...)

# %% [markdown]
# 4. 아래 NATO alphabet을 리스트로 만들고,
#
#     List Comprehension을 이용하여
#
#     각 단어의 첫번째 알파벳만으로 이루어진 리스트 만들기.
#
#     'Alfa', 'Bravo', 'Charlie', 'Delta', 'Echo', 'Foxtrot', 'Golf', 'Hotel', 'India', 'Juliett', 'Kilo', 'Lima', 'Mike', 'November', 'Oscar', 'Papa', 'Quebec', 'Romeo', 'Sierra', 'Tango', 'Uniform', 'Victor', 'Whiskey', 'X-ray', 'Yankee', 'Zulu'

# %% [markdown]
# 5. with open을 이용하여 SeoulFloating.csv 파일을 line by line 로드하여 각 구 별로 몇 개의 데이터가 있는지 출력하기. (첫줄부터 1,000,000개의 데이터만)
#
# (Output Example)
#
# {'Dobong-gu': 39911, 'Dongdaemun-gu': 39992, 'Dongjag-gu': 39991, 'Eunpyeong-gu': 39921, 'Gangbuk-gu': 40008, 'Gangdong-gu': 39909, 'Gangnam-gu': 40029, 'Gangseo-gu': 40100, 'Geumcheon-gu': 40069, 'Guro-gu': 40036, 'Gwanak-gu': 39980, 'Gwangjin-gu': 40065, 'Jongno-gu': 39997, 'Jung-gu': 40001, 'Jungnang-gu': 40017, 'Mapo-gu': 39974, 'Nowon-gu': 40027, 'Seocho-gu': 40006, 'Seodaemun-gu': 40019, 'Seongbuk-gu': 40000, 'Seongdong-gu': 39975, 'Songpa-gu': 40001, 'Yangcheon-gu': 39952, 'Yeongdeungpo-gu': 39984, 'Yongsan-gu': 40036}

# %%
# 데이터 형태
# Out:
#                date  hour  birth_year     sex province           city  fp_num
# 0        2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1        2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2        2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# 3        2020-01-01     0          20    male    Seoul  Dongdaemun-gu   27050
# 4        2020-01-01     0          20  female    Seoul     Dongjag-gu   28880
# ...             ...   ...         ...     ...      ...            ...     ...
# 1084795  2020-05-31    21          40  female    Seoul      Dobong-gu   27620
# 1084796  2020-05-31    21          40  female    Seoul      Songpa-gu   56560
# 1084797  2020-05-31    21          50  female    Seoul    Gangdong-gu   38960
# 1084798  2020-05-31    22          60  female    Seoul        Guro-gu   25420
# 1084799  2020-05-31    23          40    male    Seoul   Eunpyeong-gu   38650
#
# [1084800 rows x 7 columns]

# %% [markdown]
# 6. SeoulFloating.csv 파일에서 성북구에 사는 사람들로 이루어져 있는 데이터프레임(chunksize=100,000)을 만들고, 인덱스 초기화하기.

# %% [markdown]
# 7. List comprehension을 이용해서 fellowship에서 글자 수가 6개 이상인 단어만 출력하는 new_fellowship을 만들고 출력하여라.

# %%
fellowship = ['frodo', 'samwise', 'merry', 'aragorn', 'legolas', 'boromir', 'gimli']
# Out:
# ['samwise', 'aragorn', 'legolas', 'boromir']

# %% [markdown]
# 8. 다음은 1부터 100까자의 임의의 숫자로 이루어진 행렬을 만드는 과정이다

# %% [markdown]
# 8.1 먼저 0부터 100까지의 무작위수로 이루어진 리스트 X를 만들어보자

# %%
from random import *
x =[]
for i in range(25):
   x.______(randint(1,100))

print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7b40a2c97b84> in <module>
#       2 x =[]
#       3 for i in range(25):
# ----> 4    x.______(randint(1,100))
#       5
#       6 print(x)
#
# AttributeError: 'list' object has no attribute '______'

# %%
x[1:5]
# Out:
# [55, 4, 85, 49]

# %% [markdown]
# 8.2 List comprehension을 이용하여 5*5행렬을 만들어보자

# %%
y = [[col for col in x[0+_*_:5+_*_]] for i in range(_)]
print(y)
# Out:
# [[99, 55, 4, 85, 49], [58, 40, 32, 25, 28], [77, 60, 75, 59, 40], [29, 8, 13, 48, 6], [8, 11, 76, 75, 3]]
